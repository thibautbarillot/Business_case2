# %%
# pandas and numpy for data manipulation
import pandas as pd
import numpy as np
# %config IPCompleter.greedy=True


# matplotlit and seaborn for visualizations
import matplotlib.pyplot as plt

import seaborn as sns

# %%
import pandas as pd

# %%
df=pd.read_csv("avocado.csv")

# %%
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
df.head(3)
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany

# %%
df['AveragePrice'].tail(7)
# Out:
# 18242    1.56
# 18243    1.57
# 18244    1.63
# 18245    1.71
# 18246    1.87
# 18247    1.93
# 18248    1.62
# Name: AveragePrice, dtype: float64

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
albany_df=df[df['region']=="Albany"]

# %%
albany_df
# Out:
#        Unnamed: 0       Date  AveragePrice  Total Volume     4046       4225  \
# 0               0 2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1 2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2 2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3 2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4 2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...        ...           ...           ...      ...        ...
# 17608           7 2018-02-04          1.52       4124.96   118.38     420.36
# 17609           8 2018-01-28          1.32       6987.56   433.66     374.96
# 17610           9 2018-01-21          1.54       3346.54    14.67     253.01
# 17611          10 2018-01-14          1.47       4140.95     7.30     301.87
# 17612          11 2018-01-07          1.54       4816.90    43.51     412.17
#
# ...

# %%
albany_df.set_index("Date",inplace=True)

# %%
albany_df['AveragePrice'].plot()

# %%
albany_df['Price25ma']=albany_df['AveragePrice'].rolling(25).mean().plot()
# Out:
# C:\Users\tbarillot\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
albany_df.sort_index(inplace=True)
# Out:
# C:\Users\tbarillot\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
albany_df['AveragePrice'].plot()

# %%
# Count the occurrences of the number 4
print([1, 2, 9, 4, 5, 4, 1].count(4))

# Count the occurrences of the letter "a"
list = ["d", "a", "t", "a", "c", "a", "m", "p"]
list.count("a")
# Out:
# 2
# 3

# %%
import pandas as pd
import dateutil

# %%
data = pd.DataFrame.from_csv('data\phone_data.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-9bca613dd7da> in <module>
# ----> 1 data = pd.DataFrame.from_csv('data\phone_data.csv')
#
# AttributeError: type object 'DataFrame' has no attribute 'from_csv'

# %%
data=pd.read_csv('data\phone_data.csv')

# %%
data.head()

# %%
data['item'].count

# %%
data ['duration'][data['item']=='call'].sum()

# %%
data['network_type'].value_counts()

# %%
data['duration'].max()

# %%
data.groupby('month').first()

# %%
data.groupby('month')['duration'].sum()

# %%
df_count=data.groupby('network')['duration'].count()

# %%
df_count

# %%
data[data['item']=="call"].groupby('network')['duration'].sum()

# %%
data.groupby(['month','item'])['date'].count()

# %%
data.groupby('month', as_index=False).agg({'duration':'sum'})

# %%
df2=data.groupby(['month','item'], as_index=False).agg({'duration':'sum', 'network_type':'count','date':'first'})

# %%
 type(df_count)

# %%
df2

# %%
df2.sort_values(by=['date','network_type'],ascending=False,inplace=True)

# %%
df2

# %%
df2.set_index('date', inplace=True)

# %%
df2['duration'].plot()

# %%
data.groupby(['month','item'], as_index=False).agg({'duration':[sum,min,max], 'network_type':'count','date':'first'})

# %%
data.groupby(['month','item'], as_index=False).agg(network_type_count=('network_type','count'))

# %%
data[data['item'] == 'call'].groupby('month').agg(
    # Get max of the duration column for each group
    max_duration=('duration', max),
    # Get min of the duration column for each group
    min_duration=('duration', min),
    # Get sum of the duration column for each group
    total_duration=('duration', sum),
  
)

# %%
# Define the aggregation calculations
aggregations = {
    # work on the "duration" column
    'duration': { 
        # get the sum, and call this result 'total_duration'
        'total_duration': 'sum',  
        # get mean, call result 'average_duration'
        'average_duration': 'mean', 
        'num_calls': 'count'
    },
    # Now work on the "date" column
    'date': {     
        # Find the max, call the result "max_date" 
        'max_date': 'max',           
        'min_date': 'min',
      
    },
     # Calculate two results for the 'network' column with a list
    'network': ["count", "max"] 
}
# Perform groupby aggregation by "month", 
# but only on the rows that are of type "call"
data[data['item'] == 'call'].groupby('month').agg(aggregations)

# %%
user_usage = pd.read_csv("data\\user_usage.csv")

# %%
user_usage = pd.read_csv("data\\user_usage.csv")
user_device = pd.read_csv("data\\user_device.csv")
devices = pd.read_csv("data\\android_devices.csv")
devices.rename(columns={"Retail Branding": "manufacturer"}, inplace=True)

# %%
result = pd.merge(user_usage,
                 user_device[['use_id', 'platform', 'device']],
                 on='use_id')
result.head()
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                    21.97                    4.82     1557.33   22787
# 1                  1710.08                  136.88     7267.55   22788
# 2                  1710.08                  136.88     7267.55   22789
# 3                    94.46                   35.17      519.12   22790
# 4                    71.59                   79.26     1557.33   22792
#
#   platform    device
# 0  android  GT-I9505
# 1  android  SM-G930F
# 2  android  SM-G930F
# 3  android     D2303
# 4  android  SM-G361F

# %%
user_usage
# Out:
#      outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id
# 0                      21.97                    4.82     1557.33   22787
# 1                    1710.08                  136.88     7267.55   22788
# 2                    1710.08                  136.88     7267.55   22789
# 3                      94.46                   35.17      519.12   22790
# 4                      71.59                   79.26     1557.33   22792
# ..                       ...                     ...         ...     ...
# 235                   260.66                   68.44      896.96   25008
# 236                    97.12                   36.50     2815.00   25040
# 237                   355.93                   12.37     6828.09   25046
# 238                   632.06                  120.46     1453.16   25058
# 239                   488.70                  906.92     3089.85   25220
#
# [240 rows x 4 columns]

# %%
user_device
# Out:
#      use_id  user_id platform  platform_version                  device  \
# 0     22782    26980      ios              10.2               iPhone7,2
# 1     22783    29628  android               6.0                 Nexus 5
# 2     22784    28473  android               5.1                SM-G903F
# 3     22785    15200      ios              10.2               iPhone7,2
# 4     22786    28239  android               6.0               ONE E1003
# ..      ...      ...      ...               ...                     ...
# 267   23049    29725  android               6.0                SM-G900F
# 268   23050    29726      ios              10.2               iPhone7,2
# 269   23051    29726      ios              10.2               iPhone7,2
# 270   23052    29727      ios              10.1               iPhone8,4
# 271   23053    20257  android               5.1  Vodafone Smart ultra 6
#
#      use_type_id
# 0              2
# 1              3
# 2              1
# 3              3
# ...

# %%
result
# Out:
#      outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                      21.97                    4.82     1557.33   22787
# 1                    1710.08                  136.88     7267.55   22788
# 2                    1710.08                  136.88     7267.55   22789
# 3                      94.46                   35.17      519.12   22790
# 4                      71.59                   79.26     1557.33   22792
# ..                       ...                     ...         ...     ...
# 154                   198.59                   90.49     5191.12   23043
# 155                   198.59                   90.49     3114.67   23044
# 156                   106.65                   82.13     5191.12   23046
# 157                   344.53                   20.53      519.12   23049
# 158                    42.75                   46.83     5191.12   23053
#
#     platform                  device
# 0    android                GT-I9505
# ...
